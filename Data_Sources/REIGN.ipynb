# %% [markdown]
# # Rulers, Elections and Irregualr Governance (REIGN)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("REIGN.csv").convert_dtypes()

# %% [markdown]
# ### Rows and columns

# %%
rows, columns = df.shape
print(f"Rows: {rows}, Columns: {columns}")
# Out:
# Rows: 58725, Columns: 8

# %%
df['date'] = pd.to_datetime(df['yearmon'], errors='coerce').dt.date
df = df.convert_dtypes()
df = df.set_index(['date']).sort_index()
df = df.drop(columns=['yearmon'])

# %%
missing_by_month = df.groupby('date').count()
plt.figure(figsize=(12, 6))
sns.heatmap(missing_by_month.astype(float).T, cmap='Blues')
plt.title('Data Availabilit by Month')
plt.show()

# %% [markdown]
# ### Sample data and features

# %%
df.tail().T
# Out:
# date                                 2025-03-01 2025-03-01  2025-03-01  \
# iso3                                        BLZ        TUV         ZMB
# region_code                                 LAC        EAP         SSA
# pop                                    411106.0     9816.0  20723965.0
# REIGN_delayed_election                     <NA>       <NA>        <NA>
# REIGN_election_anticipated                 <NA>       <NA>        <NA>
# REIGN_election_now                         <NA>       <NA>        <NA>
# REIGN_irregular_election_anticipated       <NA>       <NA>        <NA>
#
# date                                  2025-03-01  2025-03-01
# iso3                                         TUN         ZWE
# region_code                                  MNA         SSA
# pop                                   12200431.0  16340822.0
# REIGN_delayed_election                      <NA>        <NA>
# REIGN_election_anticipated                  <NA>        <NA>
# REIGN_election_now                          <NA>        <NA>
# REIGN_irregular_election_anticipated        <NA>        <NA>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58725 entries, 1989-01-01 to 2025-03-01
# Data columns (total 7 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   iso3                                  58725 non-null  string
#  1   region_code                           58725 non-null  string
#  2   pop                                   58713 non-null  Float64
#  3   REIGN_delayed_election                52920 non-null  Int64
#  4   REIGN_election_anticipated            52920 non-null  Int64
#  5   REIGN_election_now                    52920 non-null  Int64
#  6   REIGN_irregular_election_anticipated  52920 non-null  Int64
# dtypes: Float64(1), Int64(4), string(2)
# memory usage: 3.9+ MB

# %% [markdown]
# ### Descriptive statistics of categorical columns

# %%
df.describe(include='string').T
# Out:
#              count unique  top   freq
# iso3         58725    135  AFG    435
# region_code  58725      6  SSA  20445

# %% [markdown]
# ### Descriptive statistics of numerical columns

# %%
df.describe().T
# Out:
#                                         count             mean  \
# pop                                   58713.0  41259533.486332
# REIGN_delayed_election                52920.0         0.012056
# REIGN_election_anticipated            52920.0         0.117876
# REIGN_election_now                    52920.0         0.020786
# REIGN_irregular_election_anticipated  52920.0         0.020937
#
#                                                    std     min        25%  \
# pop                                   153319719.021372  8662.0  2108617.0
# REIGN_delayed_election                        0.109137     0.0        0.0
# REIGN_election_anticipated                    0.322464     0.0        0.0
# REIGN_election_now                            0.142669     0.0        0.0
# REIGN_irregular_election_anticipated          0.143176     0.0        0.0
#
#                                             50%         75%           max
# pop                                   8303151.0  25698326.0  1438069596.0
# REIGN_delayed_election                      0.0         0.0           1.0
# REIGN_election_anticipated                  0.0         0.0           1.0
# REIGN_election_now                          0.0         0.0           1.0
# REIGN_irregular_election_anticipated        0.0         0.0           1.0

# %% [markdown]
# ### Deatils of missing values in the features

# %%
total_rows = len(df)
missing_count = df.isnull().sum()
missing_percent = (missing_count / total_rows * 100).round(2)
missing_df = pd.DataFrame({'Missing Count': missing_count, 'Missing Percentage (%)': missing_percent})
missing_df = missing_df.sort_values(by='Missing Percentage (%)', ascending=False)
missing_df
# Out:
#                                       Missing Count  Missing Percentage (%)
# REIGN_election_now                             5805                    9.89
# REIGN_election_anticipated                     5805                    9.89
# REIGN_delayed_election                         5805                    9.89
# REIGN_irregular_election_anticipated           5805                    9.89
# pop                                              12                    0.02
# region_code                                       0                    0.00
# iso3                                              0                    0.00

# %%
columns = missing_df[missing_df['Missing Percentage (%)'] < 70].index
df = df[columns]

numeric_df = df.select_dtypes(include=['number']).dropna()

# %%
missing_by_iso3 = df.groupby('iso3').count()
missing_by_month = df.groupby('date').count()

# %% [markdown]
# ### Availability of data by country

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(missing_by_iso3.astype(float).T, cmap='Blues')
plt.title('Data Availability by Country (ISO3)')
plt.show()

# %% [markdown]
# ### Availability of data by month

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(missing_by_month.astype(float).T, cmap='Blues')
plt.title('Data Availabilit by Month')
plt.show()

# %%
#Correlation Matrix
correlation_matrix_df = numeric_df.corr(method='pearson')

# %% [markdown]
# ### Correlation between the features

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix_df, cmap='vlag', vmin=-1, vmax=1, annot=True, fmt=".1f")
plt.title('Correlation Matrix')
plt.ylabel('Measures')
plt.tight_layout()
plt.show()

# %%
numeric_df.shape
# Out:
# (52908, 5)

# %% [markdown]
# ### Principal Components Analysis of the features

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(numeric_df)
pca = PCA(n_components=0.75)
X_pca = pca.fit_transform(X_scaled)
n_components = X_pca.shape[1]
print(f"Number of components retained: {n_components}")
columns = [f'PC{i+1}' for i in range(n_components)]
print(f"Column names for PCA components: {columns}")
# Out:
# Number of components retained: 4
# Column names for PCA components: ['PC1', 'PC2', 'PC3', 'PC4']

# %%
pca_df = pd.DataFrame(X_pca, index=numeric_df.index, columns=columns)

# %%
pca_correlation_matrix_df = pca_df.corr(method='pearson')

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(pca_correlation_matrix_df, cmap='vlag', vmin=-1, vmax=1, annot=True, fmt=".1f")
plt.title('Correlation Matrix')
plt.ylabel('Measures')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Explained Variance by Principal Component

# %%
# Get explained variance ratios
explained_variance = pca.explained_variance_ratio_
components = np.arange(1, len(explained_variance) + 1)
labels = [f'PC{i}' for i in components]

# Plot bar chart
plt.figure(figsize=(8, 5))
bars = plt.bar(x=components, height=explained_variance, tick_label=labels, color='skyblue')

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.01, f"{height:.2f}",
             ha='center', va='bottom', fontsize=9)

plt.ylabel('Explained Variance Ratio')
plt.xlabel('Principal Components')
# plt.title('Explained Variance by Principal Component')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Cumulative Explained Variance

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming `pca` has already been fitted
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

# Specify the component number (e.g., n = 4)
n = 3 # Change this to your desired component index
if n <= len(cumulative_variance):
    print(f"Cumulative explained variance at component {n}: {cumulative_variance[n-1]:.4f}")
else:
    print(f"Component {n} exceeds the total number of components ({len(cumulative_variance)}).")

# Plot the cumulative explained variance
plt.figure(figsize=(8, 5))
plt.plot(np.arange(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', color='orange')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.xticks(np.arange(1, len(cumulative_variance) + 1, step=1))
plt.ylim(0, 1)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Cumulative explained variance at component 3: 0.7367

# %%
feature_names = numeric_df.columns
components = pca.components_
loadings_df = pd.DataFrame(components.T, index=feature_names, columns=[f'PC{i+1}' for i in range(components.shape[0])])

# %% [markdown]
# ### PCA Loadings Heatmap

# %%
# create heatmap from loadings_df using sns
plt.figure(figsize=(10, 8))
sns.heatmap(loadings_df, cmap='vlag', vmin=-1, vmax=1, annot=True, fmt=".1f")
# plt.title('PCA Loadings Heatmap')
plt.xlabel('Principal Components')
plt.ylabel('Features')
plt.tight_layout()
plt.show()

# %%
# Print PCA loadings matrix as plain text
print("🔢 PCA Loadings Matrix:\n")
print(loadings_df.round(2))  # Round to 2 decimal places for readability
# Out:
# 🔢 PCA Loadings Matrix:
#
#                                        PC1   PC2   PC3   PC4
# REIGN_election_now                    0.51  0.24 -0.26 -0.64
# REIGN_election_anticipated            0.64  0.11 -0.09  0.05
# REIGN_delayed_election                0.20 -0.60  0.69 -0.36
# REIGN_irregular_election_anticipated  0.54 -0.11  0.11  0.68
# pop                                  -0.01  0.75  0.66  0.01

# %% [markdown]
# ## Physical Interpretation
#
# ### PC1-Electoral Process and Anticipation PC1 reflects electoral activity awareness and engagement, especially anticipated elections.High values here suggest countries with regular, expected, or even irregularly anticipated elections.
#
# ### PC2-Population vs. Election Delay Axis, This PC captures the relationship between population size and delayed elections.
#
# ### PC3- Structural Election Delay Complexity, This reflects a blend of election delay and population size with some negative correlation with ongoing elections. Suggests some kind of structural tension in governance in large-population countries facing election delays.
